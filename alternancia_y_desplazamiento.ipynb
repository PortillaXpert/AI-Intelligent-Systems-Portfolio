# %% [markdown]
# # **Método de Cruce Basado en Alternancia de Posiciones (AP)**

# %%
import random

#Simulacion de las variables tiempo, distancia y costo entre ciudades
n_cities = 8 #aumentar ciudades y luego aumentar generaciones, cada una en una etapa
time_matrix = [[random.randint(1, 10) for _ in range(n_cities)] for _ in range(n_cities)]
distance_matrix = [[random.randint(1, 100) for _ in range(n_cities)] for _ in range(n_cities)]
cost_matrix = [[random.randint(1, 50) for _ in range(n_cities)] for _ in range(n_cities)]

#Parametros del algoritmo genetico
population_size = 10
generations = 100
mutation_rate = 0.1

#Funcion FIT
def evaluate(individual):
    total_time, total_distance, total_cost = 0, 0, 0
    for i in range(len(individual) - 1):
        city1, city2 = individual[i], individual[i + 1]
        total_time += time_matrix[city1][city2]
        total_distance += distance_matrix[city1][city2]
        total_cost += cost_matrix[city1][city2]

    #pesos
    return 0.5 * total_time + 0.3 * total_distance + 0.2 * total_cost

#Población inicial
def generate_initial_population():
    population = []
    cities = list(range(n_cities))
    for _ in range(population_size):
        individual = cities[:]
        random.shuffle(individual)
        population.append(individual)
    return population

#Operador de cruce  (Alternancia de Posiciones)
def crossover_ap(parent1, parent2):
    child = []
    used_cities = set()

    for i in range(len(parent1)):
        if i % 2 == 0:  #Alternamos entre los padres
            if parent1[i] not in used_cities:
                child.append(parent1[i])
                used_cities.add(parent1[i])
        else:
            if parent2[i] not in used_cities:
                child.append(parent2[i])
                used_cities.add(parent2[i])

    #Rellenar con las ciudades restantes
    for city in parent1 + parent2:
        if city not in used_cities:
            child.append(city)
            used_cities.add(city)

    return child

#Operador de mutacion
def mutate(individual):
    if random.random() < mutation_rate:
        i, j = random.sample(range(len(individual)), 2)
        individual[i], individual[j] = individual[j], individual[i]

#Seleccion por torneo
def tournament_selection(population, scores, k=3):
    selected = random.sample(range(len(population)), k)
    best = min(selected, key=lambda idx: scores[idx])
    return population[best]

#Algoritmo
def genetic_algorithm():
    population = generate_initial_population()

    for generation in range(generations):
        #Evaluamos la poblacion
        scores = [evaluate(ind) for ind in population]

        #Nueva generación
        new_population = []

        while len(new_population) < population_size:
            #Seleccionamos los padres
            parent1 = tournament_selection(population, scores)
            parent2 = tournament_selection(population, scores)

            #Cruce
            child = crossover_ap(parent1, parent2)

            #Mutación
            mutate(child)

            new_population.append(child)

        population = new_population  #Reemplazo de la poblacion (Edwin por favor alterar la funcion)


        best_individual = min(population, key=evaluate)
        print(f"Generacion {generation + 1}: Mejor puntaje = {evaluate(best_individual)}")


    return min(population, key=evaluate)


best_solution = genetic_algorithm()
print(f"Mejor solucion encontrada: {best_solution}")
# Out:
# Generacion 1: Mejor puntaje = 133.3
# Generacion 2: Mejor puntaje = 133.1
# Generacion 3: Mejor puntaje = 140.4
# Generacion 4: Mejor puntaje = 138.9
# Generacion 5: Mejor puntaje = 115.2
# Generacion 6: Mejor puntaje = 103.3
# Generacion 7: Mejor puntaje = 121.6
# Generacion 8: Mejor puntaje = 121.6
# Generacion 9: Mejor puntaje = 121.6
# Generacion 10: Mejor puntaje = 121.6
# Generacion 11: Mejor puntaje = 121.6
# Generacion 12: Mejor puntaje = 121.6
# Generacion 13: Mejor puntaje = 121.6
# Generacion 14: Mejor puntaje = 121.6
# Generacion 15: Mejor puntaje = 121.6
# Generacion 16: Mejor puntaje = 121.6
# Generacion 17: Mejor puntaje = 121.6
# Generacion 18: Mejor puntaje = 121.6
# Generacion 19: Mejor puntaje = 121.6
# Generacion 20: Mejor puntaje = 121.6
# Generacion 21: Mejor puntaje = 121.6
# Generacion 22: Mejor puntaje = 121.6
# Generacion 23: Mejor puntaje = 121.6
# Generacion 24: Mejor puntaje = 121.6
# Generacion 25: Mejor puntaje = 121.6
# Generacion 26: Mejor puntaje = 121.6
# Generacion 27: Mejor puntaje = 121.6
# Generacion 28: Mejor puntaje = 121.6
# Generacion 29: Mejor puntaje = 121.6
# Generacion 30: Mejor puntaje = 121.6
# Generacion 31: Mejor puntaje = 121.6
# Generacion 32: Mejor puntaje = 121.6
# Generacion 33: Mejor puntaje = 121.6
# Generacion 34: Mejor puntaje = 121.6
# Generacion 35: Mejor puntaje = 121.6
# Generacion 36: Mejor puntaje = 121.6
# Generacion 37: Mejor puntaje = 121.6
# Generacion 38: Mejor puntaje = 121.6
# Generacion 39: Mejor puntaje = 121.6
# Generacion 40: Mejor puntaje = 121.6
# Generacion 41: Mejor puntaje = 121.6
# Generacion 42: Mejor puntaje = 121.6
# Generacion 43: Mejor puntaje = 121.6
# Generacion 44: Mejor puntaje = 121.6
# Generacion 45: Mejor puntaje = 121.6
# Generacion 46: Mejor puntaje = 121.6
# Generacion 47: Mejor puntaje = 121.6
# Generacion 48: Mejor puntaje = 121.6
# Generacion 49: Mejor puntaje = 121.6
# Generacion 50: Mejor puntaje = 121.6
# Generacion 51: Mejor puntaje = 121.6
# Generacion 52: Mejor puntaje = 121.6
# Generacion 53: Mejor puntaje = 121.6
# Generacion 54: Mejor puntaje = 121.6
# Generacion 55: Mejor puntaje = 121.6
# Generacion 56: Mejor puntaje = 120.1
# Generacion 57: Mejor puntaje = 120.1
# Generacion 58: Mejor puntaje = 120.1
# Generacion 59: Mejor puntaje = 120.1
# Generacion 60: Mejor puntaje = 120.1
# Generacion 61: Mejor puntaje = 120.1
# Generacion 62: Mejor puntaje = 120.1
# Generacion 63: Mejor puntaje = 120.1
# Generacion 64: Mejor puntaje = 120.1
# Generacion 65: Mejor puntaje = 120.1
# Generacion 66: Mejor puntaje = 120.1
# Generacion 67: Mejor puntaje = 120.1
# Generacion 68: Mejor puntaje = 120.1
# Generacion 69: Mejor puntaje = 120.1
# Generacion 70: Mejor puntaje = 115.1
# Generacion 71: Mejor puntaje = 115.1
# Generacion 72: Mejor puntaje = 115.1
# Generacion 73: Mejor puntaje = 115.1
# Generacion 74: Mejor puntaje = 115.1
# Generacion 75: Mejor puntaje = 115.1
# Generacion 76: Mejor puntaje = 115.1
# Generacion 77: Mejor puntaje = 115.1
# Generacion 78: Mejor puntaje = 115.1
# Generacion 79: Mejor puntaje = 115.1
# Generacion 80: Mejor puntaje = 115.1
# Generacion 81: Mejor puntaje = 115.1
# Generacion 82: Mejor puntaje = 115.1
# Generacion 83: Mejor puntaje = 115.1
# Generacion 84: Mejor puntaje = 115.1
# Generacion 85: Mejor puntaje = 115.1
# Generacion 86: Mejor puntaje = 115.1
# Generacion 87: Mejor puntaje = 115.1
# Generacion 88: Mejor puntaje = 115.1
# Generacion 89: Mejor puntaje = 115.1
# Generacion 90: Mejor puntaje = 115.1
# Generacion 91: Mejor puntaje = 115.1
# Generacion 92: Mejor puntaje = 115.1
# Generacion 93: Mejor puntaje = 115.1
# Generacion 94: Mejor puntaje = 115.1
# Generacion 95: Mejor puntaje = 115.1
# Generacion 96: Mejor puntaje = 115.1
# Generacion 97: Mejor puntaje = 115.1
# Generacion 98: Mejor puntaje = 115.1
# Generacion 99: Mejor puntaje = 115.1
# Generacion 100: Mejor puntaje = 115.1
# Mejor solucion encontrada: [4, 6, 2, 1, 7, 5, 0, 3]

# %% [markdown]
# # NÚMERO DE CIUDADES AUMENTADO

# %%
import random

#Simulacion de las variables tiempo, distancia y costo entre ciudades
n_cities = 40 #aumentar ciudades y luego aumentar generaciones, cada una en una etapa
time_matrix = [[random.randint(1, 10) for _ in range(n_cities)] for _ in range(n_cities)]
distance_matrix = [[random.randint(1, 100) for _ in range(n_cities)] for _ in range(n_cities)]
cost_matrix = [[random.randint(1, 50) for _ in range(n_cities)] for _ in range(n_cities)]

#Parametros del algoritmo genetico
population_size = 10
generations = 100
mutation_rate = 0.1

#Funcion FIT
def evaluate(individual):
    total_time, total_distance, total_cost = 0, 0, 0
    for i in range(len(individual) - 1):
        city1, city2 = individual[i], individual[i + 1]
        total_time += time_matrix[city1][city2]
        total_distance += distance_matrix[city1][city2]
        total_cost += cost_matrix[city1][city2]

    #pesos
    return 0.5 * total_time + 0.3 * total_distance + 0.2 * total_cost

#Población inicial
def generate_initial_population():
    population = []
    cities = list(range(n_cities))
    for _ in range(population_size):
        individual = cities[:]
        random.shuffle(individual)
        population.append(individual)
    return population

#Operador de cruce  (Alternancia de Posiciones)
def crossover_ap(parent1, parent2):
    child = []
    used_cities = set()

    for i in range(len(parent1)):
        if i % 2 == 0:  #Alternamos entre los padres
            if parent1[i] not in used_cities:
                child.append(parent1[i])
                used_cities.add(parent1[i])
        else:
            if parent2[i] not in used_cities:
                child.append(parent2[i])
                used_cities.add(parent2[i])

    #Rellenar con las ciudades restantes
    for city in parent1 + parent2:
        if city not in used_cities:
            child.append(city)
            used_cities.add(city)

    return child

#Operador de mutacion
def mutate(individual):
    if random.random() < mutation_rate:
        i, j = random.sample(range(len(individual)), 2)
        individual[i], individual[j] = individual[j], individual[i]

#Seleccion por torneo
def tournament_selection(population, scores, k=3):
    selected = random.sample(range(len(population)), k)
    best = min(selected, key=lambda idx: scores[idx])
    return population[best]

#Algoritmo
def genetic_algorithm():
    population = generate_initial_population()

    for generation in range(generations):
        #Evaluamos la poblacion
        scores = [evaluate(ind) for ind in population]

        #Nueva generación
        new_population = []

        while len(new_population) < population_size:
            #Seleccionamos los padres
            parent1 = tournament_selection(population, scores)
            parent2 = tournament_selection(population, scores)

            #Cruce
            child = crossover_ap(parent1, parent2)

            #Mutación
            mutate(child)

            new_population.append(child)

        population = new_population  #Reemplazo de la poblacion (Edwin por favor alterar la funcion)


        best_individual = min(population, key=evaluate)
        print(f"Generacion {generation + 1}: Mejor puntaje = {evaluate(best_individual)}")


    return min(population, key=evaluate)


best_solution = genetic_algorithm()
print(f"Mejor solucion encontrada: {best_solution}")
# Out:
# Generacion 1: Mejor puntaje = 810.2
# Generacion 2: Mejor puntaje = 812.5
# Generacion 3: Mejor puntaje = 784.0
# Generacion 4: Mejor puntaje = 806.1
# Generacion 5: Mejor puntaje = 805.0999999999999
# Generacion 6: Mejor puntaje = 805.0999999999999
# Generacion 7: Mejor puntaje = 803.1
# Generacion 8: Mejor puntaje = 812.7
# Generacion 9: Mejor puntaje = 812.7
# Generacion 10: Mejor puntaje = 812.7
# Generacion 11: Mejor puntaje = 812.7
# Generacion 12: Mejor puntaje = 812.7
# Generacion 13: Mejor puntaje = 812.7
# Generacion 14: Mejor puntaje = 804.5999999999999
# Generacion 15: Mejor puntaje = 803.0
# Generacion 16: Mejor puntaje = 793.1999999999999
# Generacion 17: Mejor puntaje = 751.6999999999999
# Generacion 18: Mejor puntaje = 751.6999999999999
# Generacion 19: Mejor puntaje = 750.9
# Generacion 20: Mejor puntaje = 736.0
# Generacion 21: Mejor puntaje = 709.7
# Generacion 22: Mejor puntaje = 796.1999999999999
# Generacion 23: Mejor puntaje = 780.4
# Generacion 24: Mejor puntaje = 729.7
# Generacion 25: Mejor puntaje = 729.7
# Generacion 26: Mejor puntaje = 769.3000000000001
# Generacion 27: Mejor puntaje = 777.0
# Generacion 28: Mejor puntaje = 777.0
# Generacion 29: Mejor puntaje = 777.0
# Generacion 30: Mejor puntaje = 777.0
# Generacion 31: Mejor puntaje = 755.6
# Generacion 32: Mejor puntaje = 755.6
# Generacion 33: Mejor puntaje = 753.5999999999999
# Generacion 34: Mejor puntaje = 753.5999999999999
# Generacion 35: Mejor puntaje = 753.5999999999999
# Generacion 36: Mejor puntaje = 753.5999999999999
# Generacion 37: Mejor puntaje = 749.5
# Generacion 38: Mejor puntaje = 740.3999999999999
# Generacion 39: Mejor puntaje = 706.4
# Generacion 40: Mejor puntaje = 691.9000000000001
# Generacion 41: Mejor puntaje = 705.3
# Generacion 42: Mejor puntaje = 694.2
# Generacion 43: Mejor puntaje = 694.2
# Generacion 44: Mejor puntaje = 701.4
# Generacion 45: Mejor puntaje = 685.9
# Generacion 46: Mejor puntaje = 685.9
# Generacion 47: Mejor puntaje = 700.6999999999999
# Generacion 48: Mejor puntaje = 696.9
# Generacion 49: Mejor puntaje = 700.6999999999999
# Generacion 50: Mejor puntaje = 700.6999999999999
# Generacion 51: Mejor puntaje = 700.6999999999999
# Generacion 52: Mejor puntaje = 685.9
# Generacion 53: Mejor puntaje = 685.9
# Generacion 54: Mejor puntaje = 685.9
# Generacion 55: Mejor puntaje = 667.7
# Generacion 56: Mejor puntaje = 666.5
# Generacion 57: Mejor puntaje = 666.5
# Generacion 58: Mejor puntaje = 657.1
# Generacion 59: Mejor puntaje = 657.1
# Generacion 60: Mejor puntaje = 641.0999999999999
# Generacion 61: Mejor puntaje = 633.0
# Generacion 62: Mejor puntaje = 633.0
# Generacion 63: Mejor puntaje = 633.0
# Generacion 64: Mejor puntaje = 633.0
# Generacion 65: Mejor puntaje = 633.0
# Generacion 66: Mejor puntaje = 631.1
# Generacion 67: Mejor puntaje = 631.1
# Generacion 68: Mejor puntaje = 608.5999999999999
# Generacion 69: Mejor puntaje = 608.5999999999999
# Generacion 70: Mejor puntaje = 608.5999999999999
# Generacion 71: Mejor puntaje = 608.5999999999999
# Generacion 72: Mejor puntaje = 608.5999999999999
# Generacion 73: Mejor puntaje = 626.1
# Generacion 74: Mejor puntaje = 626.1
# Generacion 75: Mejor puntaje = 623.1
# Generacion 76: Mejor puntaje = 623.1
# Generacion 77: Mejor puntaje = 623.1
# Generacion 78: Mejor puntaje = 592.4
# Generacion 79: Mejor puntaje = 592.4
# Generacion 80: Mejor puntaje = 592.4
# Generacion 81: Mejor puntaje = 633.9
# Generacion 82: Mejor puntaje = 633.9
# Generacion 83: Mejor puntaje = 633.9
# Generacion 84: Mejor puntaje = 633.9
# Generacion 85: Mejor puntaje = 633.9
# Generacion 86: Mejor puntaje = 633.9
# Generacion 87: Mejor puntaje = 633.9
# Generacion 88: Mejor puntaje = 633.9
# Generacion 89: Mejor puntaje = 633.9
# Generacion 90: Mejor puntaje = 633.9
# Generacion 91: Mejor puntaje = 633.9
# Generacion 92: Mejor puntaje = 633.9
# Generacion 93: Mejor puntaje = 633.9
# Generacion 94: Mejor puntaje = 633.9
# Generacion 95: Mejor puntaje = 633.9
# Generacion 96: Mejor puntaje = 633.9
# Generacion 97: Mejor puntaje = 633.9
# Generacion 98: Mejor puntaje = 633.9
# Generacion 99: Mejor puntaje = 633.9
# Generacion 100: Mejor puntaje = 630.5
# Mejor solucion encontrada: [3, 21, 20, 34, 8, 15, 14, 7, 5, 22, 0, 19, 33, 30, 24, 36, 23, 31, 29, 13, 25, 38, 6, 10, 28, 9, 26, 2, 4, 35, 17, 37, 32, 1, 12, 16, 27, 39, 18, 11]

# %% [markdown]
# # NUMERO DE GENERACIONES AUMENTADO

# %%
import random

#Simulacion de las variables tiempo, distancia y costo entre ciudades
n_cities = 8 #aumentar ciudades y luego aumentar generaciones, cada una en una etapa
time_matrix = [[random.randint(1, 10) for _ in range(n_cities)] for _ in range(n_cities)]
distance_matrix = [[random.randint(1, 100) for _ in range(n_cities)] for _ in range(n_cities)]
cost_matrix = [[random.randint(1, 50) for _ in range(n_cities)] for _ in range(n_cities)]

#Parametros del algoritmo genetico
population_size = 10
generations = 150
mutation_rate = 0.1

#Funcion FIT
def evaluate(individual):
    total_time, total_distance, total_cost = 0, 0, 0
    for i in range(len(individual) - 1):
        city1, city2 = individual[i], individual[i + 1]
        total_time += time_matrix[city1][city2]
        total_distance += distance_matrix[city1][city2]
        total_cost += cost_matrix[city1][city2]

    #pesos
    return 0.5 * total_time + 0.3 * total_distance + 0.2 * total_cost

#Población inicial
def generate_initial_population():
    population = []
    cities = list(range(n_cities))
    for _ in range(population_size):
        individual = cities[:]
        random.shuffle(individual)
        population.append(individual)
    return population

#Operador de cruce  (Alternancia de Posiciones)
def crossover_ap(parent1, parent2):
    child = []
    used_cities = set()

    for i in range(len(parent1)):
        if i % 2 == 0:  #Alternamos entre los padres
            if parent1[i] not in used_cities:
                child.append(parent1[i])
                used_cities.add(parent1[i])
        else:
            if parent2[i] not in used_cities:
                child.append(parent2[i])
                used_cities.add(parent2[i])

    #Rellenar con las ciudades restantes
    for city in parent1 + parent2:
        if city not in used_cities:
            child.append(city)
            used_cities.add(city)

    return child

#Operador de mutacion
def mutate(individual):
    if random.random() < mutation_rate:
        i, j = random.sample(range(len(individual)), 2)
        individual[i], individual[j] = individual[j], individual[i]

#Seleccion por torneo
def tournament_selection(population, scores, k=3):
    selected = random.sample(range(len(population)), k)
    best = min(selected, key=lambda idx: scores[idx])
    return population[best]

#Algoritmo
def genetic_algorithm():
    population = generate_initial_population()

    for generation in range(generations):
        #Evaluamos la poblacion
        scores = [evaluate(ind) for ind in population]

        #Nueva generación
        new_population = []

        while len(new_population) < population_size:
            #Seleccionamos los padres
            parent1 = tournament_selection(population, scores)
            parent2 = tournament_selection(population, scores)

            #Cruce
            child = crossover_ap(parent1, parent2)

            #Mutación
            mutate(child)

            new_population.append(child)

        population = new_population  #Reemplazo de la poblacion (Edwin por favor alterar la funcion)


        best_individual = min(population, key=evaluate)
        print(f"Generacion {generation + 1}: Mejor puntaje = {evaluate(best_individual)}")


    return min(population, key=evaluate)


best_solution = genetic_algorithm()
print(f"Mejor solucion encontrada: {best_solution}")
# Out:
# Generacion 1: Mejor puntaje = 132.2
# Generacion 2: Mejor puntaje = 119.39999999999999
# Generacion 3: Mejor puntaje = 102.7
# Generacion 4: Mejor puntaje = 102.7
# Generacion 5: Mejor puntaje = 102.7
# Generacion 6: Mejor puntaje = 102.7
# Generacion 7: Mejor puntaje = 102.7
# Generacion 8: Mejor puntaje = 102.7
# Generacion 9: Mejor puntaje = 102.7
# Generacion 10: Mejor puntaje = 102.7
# Generacion 11: Mejor puntaje = 102.7
# Generacion 12: Mejor puntaje = 102.7
# Generacion 13: Mejor puntaje = 102.7
# Generacion 14: Mejor puntaje = 102.7
# Generacion 15: Mejor puntaje = 102.7
# Generacion 16: Mejor puntaje = 102.7
# Generacion 17: Mejor puntaje = 102.7
# Generacion 18: Mejor puntaje = 102.7
# Generacion 19: Mejor puntaje = 102.7
# Generacion 20: Mejor puntaje = 102.7
# Generacion 21: Mejor puntaje = 102.7
# Generacion 22: Mejor puntaje = 102.7
# Generacion 23: Mejor puntaje = 102.7
# Generacion 24: Mejor puntaje = 102.7
# Generacion 25: Mejor puntaje = 102.7
# Generacion 26: Mejor puntaje = 102.7
# Generacion 27: Mejor puntaje = 102.7
# Generacion 28: Mejor puntaje = 102.7
# Generacion 29: Mejor puntaje = 102.7
# Generacion 30: Mejor puntaje = 102.7
# Generacion 31: Mejor puntaje = 102.7
# Generacion 32: Mejor puntaje = 100.1
# Generacion 33: Mejor puntaje = 100.1
# Generacion 34: Mejor puntaje = 100.1
# Generacion 35: Mejor puntaje = 100.1
# Generacion 36: Mejor puntaje = 100.1
# Generacion 37: Mejor puntaje = 100.1
# Generacion 38: Mejor puntaje = 100.1
# Generacion 39: Mejor puntaje = 100.1
# Generacion 40: Mejor puntaje = 100.1
# Generacion 41: Mejor puntaje = 100.1
# Generacion 42: Mejor puntaje = 100.1
# Generacion 43: Mejor puntaje = 100.1
# Generacion 44: Mejor puntaje = 100.1
# Generacion 45: Mejor puntaje = 100.1
# Generacion 46: Mejor puntaje = 100.1
# Generacion 47: Mejor puntaje = 100.1
# Generacion 48: Mejor puntaje = 100.1
# Generacion 49: Mejor puntaje = 100.1
# Generacion 50: Mejor puntaje = 100.1
# Generacion 51: Mejor puntaje = 100.1
# Generacion 52: Mejor puntaje = 100.1
# Generacion 53: Mejor puntaje = 100.1
# Generacion 54: Mejor puntaje = 100.1
# Generacion 55: Mejor puntaje = 100.1
# Generacion 56: Mejor puntaje = 100.1
# Generacion 57: Mejor puntaje = 100.1
# Generacion 58: Mejor puntaje = 100.1
# Generacion 59: Mejor puntaje = 100.1
# Generacion 60: Mejor puntaje = 100.1
# Generacion 61: Mejor puntaje = 100.1
# Generacion 62: Mejor puntaje = 100.1
# Generacion 63: Mejor puntaje = 100.1
# Generacion 64: Mejor puntaje = 90.49999999999999
# Generacion 65: Mejor puntaje = 90.49999999999999
# Generacion 66: Mejor puntaje = 90.49999999999999
# Generacion 67: Mejor puntaje = 90.49999999999999
# Generacion 68: Mejor puntaje = 90.49999999999999
# Generacion 69: Mejor puntaje = 90.49999999999999
# Generacion 70: Mejor puntaje = 90.49999999999999
# Generacion 71: Mejor puntaje = 90.49999999999999
# Generacion 72: Mejor puntaje = 90.49999999999999
# Generacion 73: Mejor puntaje = 90.49999999999999
# Generacion 74: Mejor puntaje = 90.49999999999999
# Generacion 75: Mejor puntaje = 90.49999999999999
# Generacion 76: Mejor puntaje = 90.49999999999999
# Generacion 77: Mejor puntaje = 90.49999999999999
# Generacion 78: Mejor puntaje = 90.49999999999999
# Generacion 79: Mejor puntaje = 90.49999999999999
# Generacion 80: Mejor puntaje = 90.49999999999999
# Generacion 81: Mejor puntaje = 90.49999999999999
# Generacion 82: Mejor puntaje = 90.49999999999999
# Generacion 83: Mejor puntaje = 90.49999999999999
# Generacion 84: Mejor puntaje = 90.49999999999999
# Generacion 85: Mejor puntaje = 90.49999999999999
# Generacion 86: Mejor puntaje = 90.49999999999999
# Generacion 87: Mejor puntaje = 90.49999999999999
# Generacion 88: Mejor puntaje = 90.49999999999999
# Generacion 89: Mejor puntaje = 90.49999999999999
# Generacion 90: Mejor puntaje = 90.49999999999999
# Generacion 91: Mejor puntaje = 90.49999999999999
# Generacion 92: Mejor puntaje = 90.49999999999999
# Generacion 93: Mejor puntaje = 90.49999999999999
# Generacion 94: Mejor puntaje = 90.49999999999999
# Generacion 95: Mejor puntaje = 90.49999999999999
# Generacion 96: Mejor puntaje = 90.49999999999999
# Generacion 97: Mejor puntaje = 90.49999999999999
# Generacion 98: Mejor puntaje = 90.49999999999999
# Generacion 99: Mejor puntaje = 90.49999999999999
# Generacion 100: Mejor puntaje = 90.49999999999999
# Generacion 101: Mejor puntaje = 90.49999999999999
# Generacion 102: Mejor puntaje = 90.49999999999999
# Generacion 103: Mejor puntaje = 90.49999999999999
# Generacion 104: Mejor puntaje = 90.49999999999999
# Generacion 105: Mejor puntaje = 90.49999999999999
# Generacion 106: Mejor puntaje = 90.49999999999999
# Generacion 107: Mejor puntaje = 90.49999999999999
# Generacion 108: Mejor puntaje = 90.49999999999999
# Generacion 109: Mejor puntaje = 90.49999999999999
# Generacion 110: Mejor puntaje = 90.49999999999999
# Generacion 111: Mejor puntaje = 90.49999999999999
# Generacion 112: Mejor puntaje = 90.49999999999999
# Generacion 113: Mejor puntaje = 90.49999999999999
# Generacion 114: Mejor puntaje = 90.49999999999999
# Generacion 115: Mejor puntaje = 90.49999999999999
# Generacion 116: Mejor puntaje = 90.49999999999999
# Generacion 117: Mejor puntaje = 90.49999999999999
# Generacion 118: Mejor puntaje = 90.49999999999999
# Generacion 119: Mejor puntaje = 90.49999999999999
# Generacion 120: Mejor puntaje = 90.49999999999999
# Generacion 121: Mejor puntaje = 90.49999999999999
# Generacion 122: Mejor puntaje = 90.49999999999999
# Generacion 123: Mejor puntaje = 90.49999999999999
# Generacion 124: Mejor puntaje = 90.49999999999999
# Generacion 125: Mejor puntaje = 90.49999999999999
# Generacion 126: Mejor puntaje = 90.49999999999999
# Generacion 127: Mejor puntaje = 90.49999999999999
# Generacion 128: Mejor puntaje = 90.49999999999999
# Generacion 129: Mejor puntaje = 90.49999999999999
# Generacion 130: Mejor puntaje = 90.49999999999999
# Generacion 131: Mejor puntaje = 90.49999999999999
# Generacion 132: Mejor puntaje = 90.49999999999999
# Generacion 133: Mejor puntaje = 90.49999999999999
# Generacion 134: Mejor puntaje = 90.49999999999999
# Generacion 135: Mejor puntaje = 90.49999999999999
# Generacion 136: Mejor puntaje = 90.49999999999999
# Generacion 137: Mejor puntaje = 90.49999999999999
# Generacion 138: Mejor puntaje = 90.49999999999999
# Generacion 139: Mejor puntaje = 90.49999999999999
# Generacion 140: Mejor puntaje = 90.49999999999999
# Generacion 141: Mejor puntaje = 90.49999999999999
# Generacion 142: Mejor puntaje = 90.49999999999999
# Generacion 143: Mejor puntaje = 90.49999999999999
# Generacion 144: Mejor puntaje = 90.49999999999999
# Generacion 145: Mejor puntaje = 90.49999999999999
# Generacion 146: Mejor puntaje = 90.49999999999999
# Generacion 147: Mejor puntaje = 90.49999999999999
# Generacion 148: Mejor puntaje = 90.49999999999999
# Generacion 149: Mejor puntaje = 90.49999999999999
# Generacion 150: Mejor puntaje = 90.49999999999999
# Mejor solucion encontrada: [6, 4, 7, 0, 3, 2, 1, 5]

# %% [markdown]
# #**Método de Mutación Basado en Desplazamiento (DM)**

# %%
import random


n_cities = 8
time_matrix = [[random.randint(1, 10) for _ in range(n_cities)] for _ in range(n_cities)]
distance_matrix = [[random.randint(1, 100) for _ in range(n_cities)] for _ in range(n_cities)]
cost_matrix = [[random.randint(1, 50) for _ in range(n_cities)] for _ in range(n_cities)]

#parametros del algoritmo genetico
population_size = 10
generations = 100
mutation_rate = 0.1

#funcion fit
def evaluate(individual):
    total_time, total_distance, total_cost = 0, 0, 0
    for i in range(len(individual) - 1):
        city1, city2 = individual[i], individual[i + 1]
        total_time += time_matrix[city1][city2]
        total_distance += distance_matrix[city1][city2]
        total_cost += cost_matrix[city1][city2]

    #peso de cada factor en la función de evaluación
    return 0.5 * total_time + 0.3 * total_distance + 0.2 * total_cost

#generación de la poblacion inicial
def generate_initial_population():
    population = []
    cities = list(range(n_cities))
    for _ in range(population_size):
        individual = cities[:]
        random.shuffle(individual)
        population.append(individual)
    return population

# Operador de cruce basico
def crossover(parent1, parent2):
    cut_point = len(parent1) // 2
    child = parent1[:cut_point]
    for city in parent2:
        if city not in child:
            child.append(city)
    return child

# Operador de mutación DM (Desplazamiento de subsecuencia)
def mutate_dm(individual):
    if random.random() < mutation_rate:
        #Seleccionamos una subsecuencia aleatoria
        i, j = sorted(random.sample(range(len(individual)), 2))
        subsequence = individual[i:j+1]
        remainder = individual[:i] + individual[j+1:]

        #Insertar la subsecuencia en una nueva posicion aleatoria
        insert_position = random.randint(0, len(remainder))
        new_individual = remainder[:insert_position] + subsequence + remainder[insert_position:]

        return new_individual
    return individual


def tournament_selection(population, scores, k=3):
    selected = random.sample(range(len(population)), k)
    best = min(selected, key=lambda idx: scores[idx])
    return population[best]


def genetic_algorithm():
    population = generate_initial_population()

    for generation in range(generations):

        scores = [evaluate(ind) for ind in population]


        new_population = []

        while len(new_population) < population_size:
            #Seleccion de padres
            parent1 = tournament_selection(population, scores)
            parent2 = tournament_selection(population, scores)

            #Cruce
            child = crossover(parent1, parent2)

            #Mutación DM (Desplazamiento)
            child = mutate_dm(child)

            new_population.append(child)

        population = new_population  #Reemplazo


        #Mejor individuo
        best_individual = min(population, key=evaluate)
        print(f"Generación {generation + 1}: Mejor puntaje = {evaluate(best_individual)}")

    #Devolver el mejor individuo encontrado
    return min(population, key=evaluate)

#Ejecutar el algoritmo
best_solution = genetic_algorithm()
print(f"Mejor solución encontrada: {best_solution}")
# Out:
# Generación 1: Mejor puntaje = 114.7
# Generación 2: Mejor puntaje = 110.20000000000002
# Generación 3: Mejor puntaje = 110.20000000000002
# Generación 4: Mejor puntaje = 110.20000000000002
# Generación 5: Mejor puntaje = 110.20000000000002
# Generación 6: Mejor puntaje = 110.20000000000002
# Generación 7: Mejor puntaje = 98.39999999999999
# Generación 8: Mejor puntaje = 100.6
# Generación 9: Mejor puntaje = 100.6
# Generación 10: Mejor puntaje = 100.6
# Generación 11: Mejor puntaje = 100.6
# Generación 12: Mejor puntaje = 100.6
# Generación 13: Mejor puntaje = 100.6
# Generación 14: Mejor puntaje = 100.6
# Generación 15: Mejor puntaje = 100.6
# Generación 16: Mejor puntaje = 100.6
# Generación 17: Mejor puntaje = 100.6
# Generación 18: Mejor puntaje = 100.6
# Generación 19: Mejor puntaje = 100.6
# Generación 20: Mejor puntaje = 100.6
# Generación 21: Mejor puntaje = 100.6
# Generación 22: Mejor puntaje = 100.6
# Generación 23: Mejor puntaje = 100.6
# Generación 24: Mejor puntaje = 100.6
# Generación 25: Mejor puntaje = 100.6
# Generación 26: Mejor puntaje = 100.6
# Generación 27: Mejor puntaje = 100.6
# Generación 28: Mejor puntaje = 100.6
# Generación 29: Mejor puntaje = 100.6
# Generación 30: Mejor puntaje = 100.6
# Generación 31: Mejor puntaje = 100.6
# Generación 32: Mejor puntaje = 100.6
# Generación 33: Mejor puntaje = 100.6
# Generación 34: Mejor puntaje = 100.6
# Generación 35: Mejor puntaje = 100.6
# Generación 36: Mejor puntaje = 100.6
# Generación 37: Mejor puntaje = 100.6
# Generación 38: Mejor puntaje = 100.6
# Generación 39: Mejor puntaje = 100.6
# Generación 40: Mejor puntaje = 100.6
# Generación 41: Mejor puntaje = 97.9
# Generación 42: Mejor puntaje = 97.9
# Generación 43: Mejor puntaje = 97.9
# Generación 44: Mejor puntaje = 97.9
# Generación 45: Mejor puntaje = 100.6
# Generación 46: Mejor puntaje = 100.6
# Generación 47: Mejor puntaje = 100.6
# Generación 48: Mejor puntaje = 100.6
# Generación 49: Mejor puntaje = 100.6
# Generación 50: Mejor puntaje = 100.6
# Generación 51: Mejor puntaje = 100.6
# Generación 52: Mejor puntaje = 94.0
# Generación 53: Mejor puntaje = 94.0
# Generación 54: Mejor puntaje = 94.0
# Generación 55: Mejor puntaje = 94.0
# Generación 56: Mejor puntaje = 94.0
# Generación 57: Mejor puntaje = 94.0
# Generación 58: Mejor puntaje = 94.0
# Generación 59: Mejor puntaje = 94.0
# Generación 60: Mejor puntaje = 94.0
# Generación 61: Mejor puntaje = 94.0
# Generación 62: Mejor puntaje = 94.0
# Generación 63: Mejor puntaje = 94.0
# Generación 64: Mejor puntaje = 94.0
# Generación 65: Mejor puntaje = 94.0
# Generación 66: Mejor puntaje = 94.0
# Generación 67: Mejor puntaje = 94.0
# Generación 68: Mejor puntaje = 94.0
# Generación 69: Mejor puntaje = 94.0
# Generación 70: Mejor puntaje = 94.0
# Generación 71: Mejor puntaje = 94.0
# Generación 72: Mejor puntaje = 94.0
# Generación 73: Mejor puntaje = 94.0
# Generación 74: Mejor puntaje = 94.0
# Generación 75: Mejor puntaje = 94.0
# Generación 76: Mejor puntaje = 94.0
# Generación 77: Mejor puntaje = 94.0
# Generación 78: Mejor puntaje = 94.0
# Generación 79: Mejor puntaje = 94.0
# Generación 80: Mejor puntaje = 94.0
# Generación 81: Mejor puntaje = 94.0
# Generación 82: Mejor puntaje = 94.0
# Generación 83: Mejor puntaje = 94.0
# Generación 84: Mejor puntaje = 94.0
# Generación 85: Mejor puntaje = 94.0
# Generación 86: Mejor puntaje = 94.0
# Generación 87: Mejor puntaje = 94.0
# Generación 88: Mejor puntaje = 94.0
# Generación 89: Mejor puntaje = 94.0
# Generación 90: Mejor puntaje = 94.0
# Generación 91: Mejor puntaje = 94.0
# Generación 92: Mejor puntaje = 94.0
# Generación 93: Mejor puntaje = 94.0
# Generación 94: Mejor puntaje = 94.0
# Generación 95: Mejor puntaje = 94.0
# Generación 96: Mejor puntaje = 94.0
# Generación 97: Mejor puntaje = 94.0
# Generación 98: Mejor puntaje = 94.0
# Generación 99: Mejor puntaje = 94.0
# Generación 100: Mejor puntaje = 94.0
# Mejor solución encontrada: [5, 1, 3, 6, 0, 2, 4, 7]

# %% [markdown]
# # NÚMERO DE CIUDADES AUMENTADO

# %%
import random


n_cities = 40
time_matrix = [[random.randint(1, 10) for _ in range(n_cities)] for _ in range(n_cities)]
distance_matrix = [[random.randint(1, 100) for _ in range(n_cities)] for _ in range(n_cities)]
cost_matrix = [[random.randint(1, 50) for _ in range(n_cities)] for _ in range(n_cities)]

#parametros del algoritmo genetico
population_size = 10
generations = 100
mutation_rate = 0.1

#funcion fit
def evaluate(individual):
    total_time, total_distance, total_cost = 0, 0, 0
    for i in range(len(individual) - 1):
        city1, city2 = individual[i], individual[i + 1]
        total_time += time_matrix[city1][city2]
        total_distance += distance_matrix[city1][city2]
        total_cost += cost_matrix[city1][city2]

    #peso de cada factor en la función de evaluación
    return 0.5 * total_time + 0.3 * total_distance + 0.2 * total_cost

#generación de la poblacion inicial
def generate_initial_population():
    population = []
    cities = list(range(n_cities))
    for _ in range(population_size):
        individual = cities[:]
        random.shuffle(individual)
        population.append(individual)
    return population

#Operador de cruce basico
def crossover(parent1, parent2):
    cut_point = len(parent1) // 2
    child = parent1[:cut_point]
    for city in parent2:
        if city not in child:
            child.append(city)
    return child

#Operador de mutación DM (Desplazamiento de subsecuencia)
def mutate_dm(individual):
    if random.random() < mutation_rate:
        #Seleccionamos una subsecuencia aleatoria
        i, j = sorted(random.sample(range(len(individual)), 2))
        subsequence = individual[i:j+1]
        remainder = individual[:i] + individual[j+1:]

        #Insertar la subsecuencia en una nueva posicion aleatoria
        insert_position = random.randint(0, len(remainder))
        new_individual = remainder[:insert_position] + subsequence + remainder[insert_position:]

        return new_individual
    return individual


def tournament_selection(population, scores, k=3):
    selected = random.sample(range(len(population)), k)
    best = min(selected, key=lambda idx: scores[idx])
    return population[best]


def genetic_algorithm():
    population = generate_initial_population()

    for generation in range(generations):

        scores = [evaluate(ind) for ind in population]


        new_population = []

        while len(new_population) < population_size:
            #Seleccion de padres
            parent1 = tournament_selection(population, scores)
            parent2 = tournament_selection(population, scores)

            #Cruce
            child = crossover(parent1, parent2)

            #Mutación DM (Desplazamiento)
            child = mutate_dm(child)

            new_population.append(child)

        population = new_population  #Reemplazo


        #Mejor individuo
        best_individual = min(population, key=evaluate)
        print(f"Generación {generation + 1}: Mejor puntaje = {evaluate(best_individual)}")

    #Devolver el mejor individuo encontrado
    return min(population, key=evaluate)

#Ejecutar el algoritmo
best_solution = genetic_algorithm()
print(f"Mejor solución encontrada: {best_solution}")
# Out:
# Generación 1: Mejor puntaje = 809.4000000000001
# Generación 2: Mejor puntaje = 804.7
# Generación 3: Mejor puntaje = 804.7
# Generación 4: Mejor puntaje = 804.7
# Generación 5: Mejor puntaje = 804.7
# Generación 6: Mejor puntaje = 792.3
# Generación 7: Mejor puntaje = 792.3
# Generación 8: Mejor puntaje = 792.3
# Generación 9: Mejor puntaje = 789.3000000000001
# Generación 10: Mejor puntaje = 789.3000000000001
# Generación 11: Mejor puntaje = 789.3000000000001
# Generación 12: Mejor puntaje = 789.3000000000001
# Generación 13: Mejor puntaje = 789.3000000000001
# Generación 14: Mejor puntaje = 762.2
# Generación 15: Mejor puntaje = 753.6
# Generación 16: Mejor puntaje = 753.8
# Generación 17: Mejor puntaje = 748.4999999999999
# Generación 18: Mejor puntaje = 726.6999999999999
# Generación 19: Mejor puntaje = 726.6999999999999
# Generación 20: Mejor puntaje = 718.1999999999999
# Generación 21: Mejor puntaje = 748.4999999999999
# Generación 22: Mejor puntaje = 748.4999999999999
# Generación 23: Mejor puntaje = 748.4999999999999
# Generación 24: Mejor puntaje = 744.3
# Generación 25: Mejor puntaje = 744.3
# Generación 26: Mejor puntaje = 744.3
# Generación 27: Mejor puntaje = 744.3
# Generación 28: Mejor puntaje = 744.3
# Generación 29: Mejor puntaje = 744.3
# Generación 30: Mejor puntaje = 744.3
# Generación 31: Mejor puntaje = 744.3
# Generación 32: Mejor puntaje = 744.3
# Generación 33: Mejor puntaje = 744.3
# Generación 34: Mejor puntaje = 744.3
# Generación 35: Mejor puntaje = 744.3
# Generación 36: Mejor puntaje = 744.3
# Generación 37: Mejor puntaje = 707.6
# Generación 38: Mejor puntaje = 707.6
# Generación 39: Mejor puntaje = 707.6
# Generación 40: Mejor puntaje = 703.9
# Generación 41: Mejor puntaje = 695.5999999999999
# Generación 42: Mejor puntaje = 691.5
# Generación 43: Mejor puntaje = 691.5
# Generación 44: Mejor puntaje = 691.5
# Generación 45: Mejor puntaje = 689.5
# Generación 46: Mejor puntaje = 666.9000000000001
# Generación 47: Mejor puntaje = 666.9000000000001
# Generación 48: Mejor puntaje = 666.9000000000001
# Generación 49: Mejor puntaje = 666.9000000000001
# Generación 50: Mejor puntaje = 666.9000000000001
# Generación 51: Mejor puntaje = 666.9000000000001
# Generación 52: Mejor puntaje = 666.9000000000001
# Generación 53: Mejor puntaje = 666.9000000000001
# Generación 54: Mejor puntaje = 666.9000000000001
# Generación 55: Mejor puntaje = 663.0
# Generación 56: Mejor puntaje = 663.0
# Generación 57: Mejor puntaje = 663.0
# Generación 58: Mejor puntaje = 657.9
# Generación 59: Mejor puntaje = 657.9
# Generación 60: Mejor puntaje = 657.9
# Generación 61: Mejor puntaje = 657.9
# Generación 62: Mejor puntaje = 657.9
# Generación 63: Mejor puntaje = 657.9
# Generación 64: Mejor puntaje = 657.9
# Generación 65: Mejor puntaje = 657.9
# Generación 66: Mejor puntaje = 657.9
# Generación 67: Mejor puntaje = 628.4
# Generación 68: Mejor puntaje = 628.4
# Generación 69: Mejor puntaje = 628.4
# Generación 70: Mejor puntaje = 628.4
# Generación 71: Mejor puntaje = 628.4
# Generación 72: Mejor puntaje = 625.6999999999999
# Generación 73: Mejor puntaje = 625.6999999999999
# Generación 74: Mejor puntaje = 625.6999999999999
# Generación 75: Mejor puntaje = 625.6999999999999
# Generación 76: Mejor puntaje = 625.6999999999999
# Generación 77: Mejor puntaje = 625.6999999999999
# Generación 78: Mejor puntaje = 625.6999999999999
# Generación 79: Mejor puntaje = 625.6999999999999
# Generación 80: Mejor puntaje = 625.6999999999999
# Generación 81: Mejor puntaje = 625.6999999999999
# Generación 82: Mejor puntaje = 625.6999999999999
# Generación 83: Mejor puntaje = 625.6999999999999
# Generación 84: Mejor puntaje = 625.6999999999999
# Generación 85: Mejor puntaje = 625.6999999999999
# Generación 86: Mejor puntaje = 625.6999999999999
# Generación 87: Mejor puntaje = 625.6999999999999
# Generación 88: Mejor puntaje = 625.6999999999999
# Generación 89: Mejor puntaje = 625.6999999999999
# Generación 90: Mejor puntaje = 625.6999999999999
# Generación 91: Mejor puntaje = 625.6999999999999
# Generación 92: Mejor puntaje = 625.6999999999999
# Generación 93: Mejor puntaje = 625.6999999999999
# Generación 94: Mejor puntaje = 625.6999999999999
# Generación 95: Mejor puntaje = 625.6999999999999
# Generación 96: Mejor puntaje = 625.6999999999999
# Generación 97: Mejor puntaje = 625.6999999999999
# Generación 98: Mejor puntaje = 625.6999999999999
# Generación 99: Mejor puntaje = 625.6999999999999
# Generación 100: Mejor puntaje = 625.6999999999999
# Mejor solución encontrada: [8, 19, 29, 37, 14, 11, 12, 3, 18, 35, 22, 32, 26, 2, 28, 20, 15, 31, 10, 0, 24, 17, 27, 34, 21, 23, 4, 33, 13, 16, 5, 30, 7, 36, 1, 9, 25, 39, 38, 6]

# %% [markdown]
# # NÚMERO DE GENERACIONES AUMENTADO

# %%
import random


n_cities = 8
time_matrix = [[random.randint(1, 10) for _ in range(n_cities)] for _ in range(n_cities)]
distance_matrix = [[random.randint(1, 100) for _ in range(n_cities)] for _ in range(n_cities)]
cost_matrix = [[random.randint(1, 50) for _ in range(n_cities)] for _ in range(n_cities)]

#parametros del algoritmo genetico
population_size = 10
generations = 150
mutation_rate = 0.1

#funcion fit
def evaluate(individual):
    total_time, total_distance, total_cost = 0, 0, 0
    for i in range(len(individual) - 1):
        city1, city2 = individual[i], individual[i + 1]
        total_time += time_matrix[city1][city2]
        total_distance += distance_matrix[city1][city2]
        total_cost += cost_matrix[city1][city2]

    #peso de cada factor en la función de evaluación
    return 0.5 * total_time + 0.3 * total_distance + 0.2 * total_cost

#generación de la poblacion inicial
def generate_initial_population():
    population = []
    cities = list(range(n_cities))
    for _ in range(population_size):
        individual = cities[:]
        random.shuffle(individual)
        population.append(individual)
    return population

#Operador de cruce basico
def crossover(parent1, parent2):
    cut_point = len(parent1) // 2
    child = parent1[:cut_point]
    for city in parent2:
        if city not in child:
            child.append(city)
    return child

#Operador de mutación DM (Desplazamiento de subsecuencia)
def mutate_dm(individual):
    if random.random() < mutation_rate:
        #Seleccionamos una subsecuencia aleatoria
        i, j = sorted(random.sample(range(len(individual)), 2))
        subsequence = individual[i:j+1]
        remainder = individual[:i] + individual[j+1:]

        #Insertar la subsecuencia en una nueva posicion aleatoria
        insert_position = random.randint(0, len(remainder))
        new_individual = remainder[:insert_position] + subsequence + remainder[insert_position:]

        return new_individual
    return individual


def tournament_selection(population, scores, k=3):
    selected = random.sample(range(len(population)), k)
    best = min(selected, key=lambda idx: scores[idx])
    return population[best]


def genetic_algorithm():
    population = generate_initial_population()

    for generation in range(generations):

        scores = [evaluate(ind) for ind in population]


        new_population = []

        while len(new_population) < population_size:
            #Seleccion de padres
            parent1 = tournament_selection(population, scores)
            parent2 = tournament_selection(population, scores)

            #Cruce
            child = crossover(parent1, parent2)

            #Mutación DM (Desplazamiento)
            child = mutate_dm(child)

            new_population.append(child)

        population = new_population  #Reemplazo


        #Mejor individuo
        best_individual = min(population, key=evaluate)
        print(f"Generación {generation + 1}: Mejor puntaje = {evaluate(best_individual)}")

    #Devolver el mejor individuo encontrado
    return min(population, key=evaluate)

#Ejecutar el algoritmo
best_solution = genetic_algorithm()
print(f"Mejor solución encontrada: {best_solution}")
# Out:
# Generación 1: Mejor puntaje = 118.1
# Generación 2: Mejor puntaje = 118.1
# Generación 3: Mejor puntaje = 118.1
# Generación 4: Mejor puntaje = 118.1
# Generación 5: Mejor puntaje = 118.1
# Generación 6: Mejor puntaje = 118.1
# Generación 7: Mejor puntaje = 118.1
# Generación 8: Mejor puntaje = 118.1
# Generación 9: Mejor puntaje = 118.1
# Generación 10: Mejor puntaje = 99.9
# Generación 11: Mejor puntaje = 99.9
# Generación 12: Mejor puntaje = 99.9
# Generación 13: Mejor puntaje = 99.9
# Generación 14: Mejor puntaje = 99.9
# Generación 15: Mejor puntaje = 99.9
# Generación 16: Mejor puntaje = 99.9
# Generación 17: Mejor puntaje = 99.9
# Generación 18: Mejor puntaje = 99.9
# Generación 19: Mejor puntaje = 99.9
# Generación 20: Mejor puntaje = 99.9
# Generación 21: Mejor puntaje = 99.9
# Generación 22: Mejor puntaje = 99.9
# Generación 23: Mejor puntaje = 99.9
# Generación 24: Mejor puntaje = 99.9
# Generación 25: Mejor puntaje = 99.9
# Generación 26: Mejor puntaje = 99.9
# Generación 27: Mejor puntaje = 99.9
# Generación 28: Mejor puntaje = 88.5
# Generación 29: Mejor puntaje = 88.5
# Generación 30: Mejor puntaje = 88.5
# Generación 31: Mejor puntaje = 88.5
# Generación 32: Mejor puntaje = 88.5
# Generación 33: Mejor puntaje = 88.5
# Generación 34: Mejor puntaje = 88.5
# Generación 35: Mejor puntaje = 88.5
# Generación 36: Mejor puntaje = 88.5
# Generación 37: Mejor puntaje = 88.5
# Generación 38: Mejor puntaje = 88.5
# Generación 39: Mejor puntaje = 88.5
# Generación 40: Mejor puntaje = 88.5
# Generación 41: Mejor puntaje = 88.5
# Generación 42: Mejor puntaje = 88.5
# Generación 43: Mejor puntaje = 83.4
# Generación 44: Mejor puntaje = 83.4
# Generación 45: Mejor puntaje = 83.4
# Generación 46: Mejor puntaje = 83.4
# Generación 47: Mejor puntaje = 83.4
# Generación 48: Mejor puntaje = 83.4
# Generación 49: Mejor puntaje = 83.4
# Generación 50: Mejor puntaje = 83.4
# Generación 51: Mejor puntaje = 83.4
# Generación 52: Mejor puntaje = 83.4
# Generación 53: Mejor puntaje = 83.4
# Generación 54: Mejor puntaje = 83.4
# Generación 55: Mejor puntaje = 83.4
# Generación 56: Mejor puntaje = 83.4
# Generación 57: Mejor puntaje = 83.4
# Generación 58: Mejor puntaje = 83.4
# Generación 59: Mejor puntaje = 83.4
# Generación 60: Mejor puntaje = 83.4
# Generación 61: Mejor puntaje = 83.4
# Generación 62: Mejor puntaje = 83.4
# Generación 63: Mejor puntaje = 83.4
# Generación 64: Mejor puntaje = 83.4
# Generación 65: Mejor puntaje = 83.4
# Generación 66: Mejor puntaje = 83.4
# Generación 67: Mejor puntaje = 83.4
# Generación 68: Mejor puntaje = 83.4
# Generación 69: Mejor puntaje = 83.4
# Generación 70: Mejor puntaje = 83.4
# Generación 71: Mejor puntaje = 83.4
# Generación 72: Mejor puntaje = 83.4
# Generación 73: Mejor puntaje = 83.4
# Generación 74: Mejor puntaje = 83.4
# Generación 75: Mejor puntaje = 83.4
# Generación 76: Mejor puntaje = 83.4
# Generación 77: Mejor puntaje = 83.4
# Generación 78: Mejor puntaje = 83.4
# Generación 79: Mejor puntaje = 83.4
# Generación 80: Mejor puntaje = 83.4
# Generación 81: Mejor puntaje = 83.4
# Generación 82: Mejor puntaje = 83.4
# Generación 83: Mejor puntaje = 83.4
# Generación 84: Mejor puntaje = 83.4
# Generación 85: Mejor puntaje = 83.4
# Generación 86: Mejor puntaje = 83.4
# Generación 87: Mejor puntaje = 83.4
# Generación 88: Mejor puntaje = 83.4
# Generación 89: Mejor puntaje = 83.4
# Generación 90: Mejor puntaje = 83.4
# Generación 91: Mejor puntaje = 83.4
# Generación 92: Mejor puntaje = 83.4
# Generación 93: Mejor puntaje = 83.4
# Generación 94: Mejor puntaje = 83.4
# Generación 95: Mejor puntaje = 83.4
# Generación 96: Mejor puntaje = 83.4
# Generación 97: Mejor puntaje = 83.4
# Generación 98: Mejor puntaje = 83.4
# Generación 99: Mejor puntaje = 83.4
# Generación 100: Mejor puntaje = 83.4
# Generación 101: Mejor puntaje = 83.4
# Generación 102: Mejor puntaje = 83.4
# Generación 103: Mejor puntaje = 83.4
# Generación 104: Mejor puntaje = 83.4
# Generación 105: Mejor puntaje = 83.4
# Generación 106: Mejor puntaje = 83.4
# Generación 107: Mejor puntaje = 83.4
# Generación 108: Mejor puntaje = 83.4
# Generación 109: Mejor puntaje = 83.4
# Generación 110: Mejor puntaje = 83.4
# Generación 111: Mejor puntaje = 83.4
# Generación 112: Mejor puntaje = 83.4
# Generación 113: Mejor puntaje = 83.4
# Generación 114: Mejor puntaje = 83.4
# Generación 115: Mejor puntaje = 83.4
# Generación 116: Mejor puntaje = 83.4
# Generación 117: Mejor puntaje = 83.4
# Generación 118: Mejor puntaje = 83.4
# Generación 119: Mejor puntaje = 83.4
# Generación 120: Mejor puntaje = 83.4
# Generación 121: Mejor puntaje = 83.4
# Generación 122: Mejor puntaje = 83.4
# Generación 123: Mejor puntaje = 83.4
# Generación 124: Mejor puntaje = 83.4
# Generación 125: Mejor puntaje = 83.4
# Generación 126: Mejor puntaje = 83.4
# Generación 127: Mejor puntaje = 83.4
# Generación 128: Mejor puntaje = 83.4
# Generación 129: Mejor puntaje = 83.4
# Generación 130: Mejor puntaje = 83.4
# Generación 131: Mejor puntaje = 83.4
# Generación 132: Mejor puntaje = 83.4
# Generación 133: Mejor puntaje = 83.4
# Generación 134: Mejor puntaje = 83.4
# Generación 135: Mejor puntaje = 83.4
# Generación 136: Mejor puntaje = 83.4
# Generación 137: Mejor puntaje = 83.4
# Generación 138: Mejor puntaje = 83.4
# Generación 139: Mejor puntaje = 83.4
# Generación 140: Mejor puntaje = 83.4
# Generación 141: Mejor puntaje = 83.4
# Generación 142: Mejor puntaje = 83.4
# Generación 143: Mejor puntaje = 83.4
# Generación 144: Mejor puntaje = 83.4
# Generación 145: Mejor puntaje = 83.4
# Generación 146: Mejor puntaje = 83.4
# Generación 147: Mejor puntaje = 83.4
# Generación 148: Mejor puntaje = 83.4
# Generación 149: Mejor puntaje = 83.4
# Generación 150: Mejor puntaje = 83.4
# Mejor solución encontrada: [4, 1, 5, 6, 7, 3, 2, 0]
